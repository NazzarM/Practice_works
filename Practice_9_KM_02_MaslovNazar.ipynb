# %% [markdown]
# # **Курс "Програмування на мові Python"**
#
# ##### Викладачі:
# ##### Борисенко Павло Борисович
# ##### Щьоголєв Максим Олегович

# %% [markdown]
# ## **Практичне зайняття №9**
#
# ### Тема: "Лямбда-функції. Функції вищих порядків"

# %% [markdown]
# ### **Завдання 1 (1 бал)**
#
# Продавець роздрібного товару влаштовує розпродаж. Для всіх товарів знижка однакова - 60%. Щоб вивісити нові цінники, продавець хоче скласти таблицю, в якій для кожного товару буде підрахована його нова вартість та сума знижки.
#
# Написати програму, яка буде генерувати таку таблицю. Вартість одиниць товарів до розпродажу подано у списку products_list.
#
# 1. Для підрахунку невідомих значень повинні використовуватись вбудовані функції вищих порядків.
#
# 2. Вартість з урахуванням знижки та суми знижок для кожного товару повинні зберігатись у двох окремих списках. Порядок товарів у нових списках повинен бути такий самий, як і в списку products_list.
#
# 3. Кожне підраховане числове значення має бути округлене до сотих.
#
# 4. Дані повинні виводитись у вигляді:
#
# **Discount table:**
#
# **29.25 11.7 17.55**
#
# **48.99 19.6 29.39**
#
# **...**
#
#
# products_list = [[29.25, 48.99, 99.98, 124.65, 214.30, 543.90, 799.85]]

# %%
products_list = [29.25, 48.99, 99.98, 124.65, 214.30, 543.90, 799.85]
new_products_list = list(map(lambda x: round(x*0.4, 2), products_list))
discount_list = list(map(lambda x, y: x - y, products_list, new_products_list))
print("Discount table:")
for i in zip(products_list, new_products_list, discount_list):
    print(*i)
# Out:
# Discount table:
# 29.25 11.7 17.55
# 48.99 19.6 29.39
# 99.98 39.99 59.99
# 124.65 49.86 74.79
# 214.3 85.72 128.58
# 543.9 217.56 326.34
# 799.85 319.94 479.91

# %% [markdown]
# ### **Завдання 2 (2 бали)**
#
# Зазвичай рік має 365 днів. Однак у високосні роки додається ще один день - 29 лютого. Правила визначення високосного року такі:
#
# - Будь-який рік, що ділиться на 400 - високосний.
#
# - З тих років, що залишились, будь-який рік, що ділиться на 100 - **не** високосний.
#
# - З тих років, що залишились, будь-який рік, що ділиться на 4 - високосний.
#
# - Усі інші роки, що залишились - **не** високосні.
#
# 1) Створіть функцію, в якій за допомогою вбудованих функцій вищих порядків будуть визначатися високосні роки серед перелічених років у списку years. Створена функція має повертати список високосних років.
#
# 2) Створіть функцію вищих порядків, яка прийматиме на вхід попередню функцію та визначатиме кількість днів у місяці. Також функція повинна приймати на вхід ще 2 параметри: ціле число від 1 до 12 (місяць) та рік, як ціле чотирицифрове число. Ці значення корисувач має вводити з клавіатури. Перевірку введених даних слід виконувати поза межами функцій.

# %%
import numpy as np

years = np.arange(1900, 2020+1, 1)
months_of_30 = (4,6,9,11)
months_of_31 = (1,3,5,7,8,10,12)
visokisniy_god = 2

def visokosni():
    visokosni_rik = list(filter(lambda x: x%400==0 or x%100!=0 and x%4==0, list(years)))
    return visokosni_rik

def days_in_month(months, yearss, high_year_list):
    if months in months_of_30:
        return 30
    elif months in months_of_31:
        return 31
    elif months is visokisniy_god and yearss in high_year_list:
        return 29
    elif months is visokisniy_god and yearss not in high_year_list:
        return 28
    
def ask_for_month():
    global month
    try:
        month = int(input("Month: "))
        if month >= 13 or month <=0:
            raise ValueError
            ask_for_month()
    except ValueError:
        print("Invalid format. Month can not be more than 12 and less than 1")
        ask_for_month()

def ask_for_year():
    global year
    try:
        year = int(input("Year(1900-2020): "))
        if year <1900 or year > 2020:
            raise ValueError
            ask_for_year()
    except ValueError:
        print("Invalid format. The year must be in the specified range (1900-2020)")
        ask_for_year()

ask_for_month()
ask_for_year()
days_count = days_in_month(month, year, visokosni())
print("The amounf of days in {} month of {} year is {}".format(month,year,days_count))
# Out:
# The amounf of days in 2 month of 2019 year is 28
